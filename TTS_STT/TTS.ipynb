# %%
import torch
import soundfile as sf
from qwen_tts import Qwen3TTSModel
from fastapi import FastAPI
from fastapi.responses import FileResponse

# %%
app = FastAPI()

# %%
model = Qwen3TTSModel.from_pretrained(
    "Qwen/Qwen3-TTS-12Hz-1.7B-CustomVoice",
    device_map="cuda:0",
    dtype=torch.bfloat16,
)
# Out:
# ...
# Fetching 4 files: 100%|██████████| 4/4 [03:22<00:00, 50.53s/it]
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 52c5bfdf-b845-438a-b372-3623453a1a42)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen3-TTS-12Hz-1.7B-CustomVoice/resolve/main/speech_tokenizer/config.json
# Retrying in 1s [Retry 1/5].

# %%
@app.post("/tts")
async def generate(text: str):
    wavs, sr = model.generate_custom_voice(
        text=text,
        voice="Chelsie",
        language="English",
    )
    sf.write("TTSaudio/output.wav", wavs[0], sr)
    return FileResponse("TTSaudio/output.wav", media_type="audio/wav")

# %%
# wavs, sr = model.generate_custom_voice(
#     text="water",
#     # voice="Chelsie",
#     language="English",
#     instruction="Speak in a professional tone.",
#     speaker=""
# )
# Out:
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.

# %%
import os
print(os.getcwd())  # Affiche le répertoire actuel
# Out:
# c:\Users\LENOVO\Digital-Eyes\TTS_STT

# %%
sf.write("TTSaudio/custom_voice.wav", wavs[0], sr)
print(f"✅ Audio saved! Sample rate: {sr}Hz")
# Out:
# ✅ Audio saved! Sample rate: 24000Hz

# %%
from IPython.display import Audio
Audio("TTSaudio/custom_voice.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
